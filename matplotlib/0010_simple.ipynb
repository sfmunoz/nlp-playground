# %% [markdown]
# # Matplotlib simple examples
#
# - https://matplotlib.org/
# - https://github.com/matplotlib/matplotlib

# %%
# %reset -f
import matplotlib.pyplot as plt
plt.plot([1,-1,3,4,3,5,2,4])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot([1,2,3,4,5,5.2,5.3],[1,4,-2,16,3,3.5,2.2],'yo')
plt.axis((-2,6,-5,20))
plt.show()
